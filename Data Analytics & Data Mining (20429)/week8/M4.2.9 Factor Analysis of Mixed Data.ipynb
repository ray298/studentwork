# %% [markdown]
# #**Factor Analysis of Mixed Data(FAMD)**
#
# In the previous 4 steps we have examined how we can use principal component and multiple correspondence analysis to help us search for latent factors for both continous and categorical data respectively. The problem we have is that most of our datasets have both categorical and quantative data.
#
# FAMD is a method dedicated to explore data with both continuous and categorical variables. It can be seen roughly as a mixed between PCA and MCA. More precisely, the continuous variables are scaled to unit variance and the categorical variables are transformed into a set of dummy variables and then scaled using the specific scaling of MCA. This ensures to balance the influence of both continous and categorical variables in the analysis. It means that both variables are on a equal foot to determine the dimensions of variability. This method allows one to study the similarities between individuals taking into account mixed variables and to study the relationships between all the variables. It also provides graphical outputs such as the representation of the individuals, the correlation circle for the continuous variables and representations of the categories of the categorical variables, and also specific graphs to visulaize the associations between both type of variables,[RDocumentation](https://www.rdocumentation.org/packages/FactoMineR/versions/2.0/topics/FAMD).
#
# Now the issue we have is that the libraries that are available in Python are not as well established as those provided by R, the statistical programming language. You can find out how to install R [here](https://cran.r-project.org/bin/windows/base/), and this [video](http://www.sthda.com/english/articles/22-principal-component-methods-videos/72-famd-in-r-using-factominer-quick-scripts-and-videos/) shows you how to do FAMD using the R FactoMineR library. There is an implementation of a FAMD using python's "prince" library.

# %%
# !pip install light_famd
# Out:
# Requirement already satisfied: light_famd in /usr/local/lib/python3.11/dist-packages (0.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from light_famd) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from light_famd) (1.13.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from light_famd) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from light_famd) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->light_famd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->light_famd) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->light_famd) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->light_famd) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->light_famd) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->light_famd) (1.17.0)

# %% [markdown]
# We will create another toy dataset with both categorical and continous data.

# %%
from light_famd import FAMD
import pandas as pd
import numpy as np
#from sklearn.preprocessing import OneHotEncoder
X_n = pd.DataFrame(data=np.random.randint(0,100,size=(100,2)),columns=list('AB'))
X_c =pd.DataFrame(np.random.choice(list('abcde'),size=(100,4),replace=True),columns =list('CDEF'))
X=pd.concat([X_n,X_c],axis=1)
print(X)
X.to_csv('FAMD_dataset.csv')
# Out:
#      A   B  C  D  E  F
# 0   42   9  d  e  c  b
# 1   73  91  e  b  b  a
# 2   20  59  a  c  d  b
# 3   67  13  a  a  b  a
# 4    8  73  b  d  b  d
# ..  ..  .. .. .. .. ..
# 95  91  72  e  b  e  d
# 96  76  91  c  a  c  d
# 97  46  62  c  a  b  d
# 98  39  40  b  c  a  a
# 99  49  84  c  b  a  c
#
# [100 rows x 6 columns]

# %%
# !pip install prince
# Out:
# Collecting prince
#   Downloading prince-0.15.0-py3-none-any.whl.metadata (641 bytes)
# Requirement already satisfied: altair<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from prince) (5.5.0)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from prince) (2.2.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from prince) (1.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6.0.0,>=5.0.0->prince) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6.0.0,>=5.0.0->prince) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6.0.0,>=5.0.0->prince) (1.26.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from altair<6.0.0,>=5.0.0->prince) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from altair<6.0.0,>=5.0.0->prince) (4.12.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.2.0->prince) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.2.0->prince) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.2.0->prince) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.2.0->prince) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.5.1->prince) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.5.1->prince) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.5.1->prince) (3.5.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=5.0.0->prince) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=5.0.0->prince) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=5.0.0->prince) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=5.0.0->prince) (0.22.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.0->prince) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6.0.0,>=5.0.0->prince) (3.0.2)
# Downloading prince-0.15.0-py3-none-any.whl (417 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.3/417.3 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: prince
# Successfully installed prince-0.15.0

# %% [markdown]
# Now let use to FAMD to build a 4 component structure on the X dataset.

# %%
import pandas as pd
import numpy as np
import prince
X = pd.read_csv('/content/FAMD_dataset.csv')
X = X.astype({'A':'float','B':'float'})
print(type(X['A'][0]))

famd = prince.FAMD(
    n_components=5,
    n_iter=5,
    copy=True,
    check_input=True,
    random_state=42,
    engine="sklearn",
    handle_unknown="error"  # same parameter as sklearn.preprocessing.OneHotEncoder
)
famd = famd.fit(X)
# Out:
# <class 'numpy.float64'>

# %%
print(famd.eigenvalues_summary)

print(famd.transform(X))
# Out:
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              6.482         2.24%                      2.24%
# 1              6.373         2.20%                      4.44%
# 2              6.071         2.10%                      6.54%
# 3              5.915         2.04%                      8.58%
# 4              5.617         1.94%                     10.52%
# component         0         1         2         3         4
# 0         -2.085424 -4.598680  1.113134  1.936872  4.300459
# 1          2.328936  0.302466 -0.139033  3.311255  1.047766
# 2         -4.718060  1.380350 -1.042961  2.205276 -0.883059
# 3         -1.674276  0.406171 -1.442518 -0.555289 -0.313671
# 4          4.284676 -2.548779 -0.724078 -1.920266 -0.315264
# ..              ...       ...       ...       ...       ...
# 95         4.998120 -0.753455 -1.841424  3.897185 -0.428353
# 96         1.283051 -0.821468  0.057732 -2.696713  3.322828
# 97         2.153163  0.388943 -2.542013 -4.031461  3.488404
# 98        -0.510925  1.929453  4.665622  0.791117 -3.824977
# 99         1.647235  3.073677  2.931468 -2.052881  1.314802
#
# [100 rows x 5 columns]

# %% [markdown]
# #**Conclusions**
#
# We have implemented a FAMD using  "prince".
