# %% [markdown]
# # **CRMs vs ERPs**
#
# In this step we will Customer relationship management (CRM) and enterprise resource planning (ERP) programs. Both systems can be incredibly useful when attempting to extract data on a business performance. Go to the following [link](https://simply-crm.com/blog/difference-between-erp-and-crm/) and study the content.
#
# When you have read it try and answer the following questions:
#
# * Which system is best to extract data about your customers future needs and behavours?
#
# * What type of system is Salesforce?
#
# * Is there an API for Salesforce?
