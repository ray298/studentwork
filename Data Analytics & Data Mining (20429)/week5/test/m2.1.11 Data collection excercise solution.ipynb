# %% [markdown]
# Data extraction Excercise
#
# The following [link](http://www.csgnetwork.com/llinfotable.html) gives all the capital cites of the world and their latitude and longtitude. Scrape these.
#
# What issues did you find? Did you get a result for each city?

# %%
import pandas as pd
dfs = pd.read_html('http://www.csgnetwork.com/llinfotable.html',encoding='iso-8859-1')
print(dfs)
# Out:
# /usr/local/lib/python3.11/dist-packages/bs4/__init__.py:339: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn(
# [                                                  0   1   2   3   4   5   6   \
# 0                                                NaN NaN NaN NaN NaN NaN NaN
# 1  Home | Top Free Apps | CALCULATORS and CONVERT... NaN NaN NaN NaN NaN NaN
#
#    7   8   9   10  11  12
# 0 NaN NaN NaN NaN NaN NaN
# 1 NaN NaN NaN NaN NaN NaN  ,                                                      0  \
# 0    Countries, Capitals, Latitude and Longitude Ta...
# 1    This table is a quick reference for countries,...
# 2    (adsbygoogle = window.adsbygoogle || []).push(...
# 3    Country  Capital  Latitude  Longitude  Afghani...
# 4                                              Country
# ..                                                 ...
# 200                                          Venezuela
# ...

# %%
print(dfs[5])
# Out:
#                   0          1         2          3
# 0           Country    Capital  Latitude  Longitude
# 1       Afghanistan      Kabul   34°28'N    69°11'E
# 2           Albania     Tirane   41°18'N    19°49'E
# 3           Algeria    Algiers   36°42'N    03°08'E
# 4    American Samoa  Pago Pago   14°16'S   170°43'W
# ..              ...        ...       ...        ...
# 196       Venezuela    Caracas   10°30'N    66°55'W
# 197        Viet Nam      Hanoi   21°05'N   105°55'E
# 198      Yugoslavia   Belgrade   44°50'N    20°37'E
# 199          Zambia     Lusaka   15°28'S    28°16'E
# 200        Zimbabwe     Harare   17°43'S    31°02'E
#
# [201 rows x 4 columns]
