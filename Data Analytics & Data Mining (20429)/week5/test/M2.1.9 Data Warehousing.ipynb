# %% [markdown]
# * # Data Warehousing
#
# Data warehouses are generally constructed to store vast amounts of intergrated organisational data and are used to help these organisations create reports. They are usually derived from production data. The article [here](https://www.omicsonline.org/open-access/what-is-data-warehouse-2277-1891-1000117.php?aid=12878) outlines the use of a data warehouse and why we build them?
#
#
# * Why would organisations need a data warehouse?
# * Have you used one before and what were the benifts over just storing the data in a single database?
