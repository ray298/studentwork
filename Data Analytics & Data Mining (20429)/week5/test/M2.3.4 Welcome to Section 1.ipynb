# %% [markdown]
# # **Pre-processing Data II**
#
# Welcome to the next topic of MOOC2. In this topic we will continoue to explore some of the techniques required to pre-process data. In this topic we will exam the following topics:
#
# * Idenitfying Univariare Outliers
# * Identify Multivatriate Outliers
# * Use control charts as example techniques to identify outliers
# * Understand what hetroscedasstic data is
# * Describe Benfords law
# * Use discritization techniques to handle noisy data
# * Understand Exponential Smoothing
#
# We will begin with explaining what an outlier is and how it can impact your analysis, and then move through each of the above sections. We will as usual implment code snipets throughout this topic and we will do a quick quiz at the end.
